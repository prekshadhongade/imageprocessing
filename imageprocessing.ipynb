# %% [markdown]
# <a href="https://colab.research.google.com/github/prekshadhongade/imageprocessing/blob/main/imageprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !wget 'https://tse2.mm.bing.net/th?id=OIP.pJCU0PKFKXqhd9SO40OObwHaE8&pid=Api&P=0&h=180'
# Out:
# --2024-08-15 08:24:24--  https://tse2.mm.bing.net/th?id=OIP.pJCU0PKFKXqhd9SO40OObwHaE8&pid=Api&P=0&h=180
# Resolving tse2.mm.bing.net (tse2.mm.bing.net)... 150.171.27.10, 150.171.28.10, 2620:1ec:33::10, ...
# Connecting to tse2.mm.bing.net (tse2.mm.bing.net)|150.171.27.10|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 9674 (9.4K) [image/jpeg]
# Saving to: ‘th?id=OIP.pJCU0PKFKXqhd9SO40OObwHaE8&pid=Api&P=0&h=180’
#
# th?id=OIP.pJCU0PKFK 100%[===================>]   9.45K  --.-KB/s    in 0s
#
# 2024-08-15 08:24:25 (211 MB/s) - ‘th?id=OIP.pJCU0PKFKXqhd9SO40OObwHaE8&pid=Api&P=0&h=180’ saved [9674/9674]

# %%
 import matplotlib.image as mpimg
 import matplotlib.pyplot as plt

# %%
img = mpimg.imread('/content/sunflower.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
print(img.shape)
# Out:
# (180, 270, 3)

# %%
print(img)
# Out:
# [[[232 231 226]
#   [231 230 225]
#   [230 229 224]
#   ...
#   [200 177 159]
#   [201 172 154]
#   [201 170 150]]
#
#  [[230 229 224]
#   [229 228 223]
#   [228 227 222]
#   ...
#   [191 168 150]
#   [191 162 144]
#   [190 159 139]]
#
#  [[228 227 222]
#   [228 227 222]
#   [227 226 221]
#   ...
#   [184 158 141]
#   [182 151 133]
#   [180 147 128]]
#
#  ...
#
#  [[181 153 149]
#   [174 146 142]
#   [171 143 139]
#   ...
#   [176 164 166]
#   [180 167 174]
#   [183 172 178]]
#
#  [[181 153 149]
#   [175 147 143]
#   [172 144 140]
#   ...
#   [177 165 167]
#   [179 166 173]
#   [181 170 176]]
#
#  [[182 154 150]
#   [175 147 143]
#   [172 144 140]
#   ...
#   [177 165 167]
#   [178 165 172]
#   [180 169 175]]]

# %%
img_plot=plt.imshow(img)
plt.show()

# %%
from PIL import Image

# %%
img=Image.open('/content/sunflower.jpg')
img_resized=img.resize((200,200))

# %%
img_resized.save('sunflower_resized.jpg')

# %%
img_res = mpimg.imread('/content/sunflower_resized.jpg')
img_plot=plt.imshow(img_res)
plt.show()

# %%
print(img_res.shape)
# Out:
# (200, 200, 3)

# %%
import cv2

# %%
img=cv2.imread('/content/sunflower.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img.shape
# Out:
# (180, 270, 3)

# %%
grayscale_image=cv2.cvtColor(img,cv2.COLOR_RGB2GRAY)

# %%
type(grayscale_image)
# Out:
# numpy.ndarray

# %%
grayscale_image.shape
# Out:
# (180, 270)

# %%
from google.colab.patches import cv2_imshow

# %%
cv2_imshow(grayscale_image)
# Out:
# <PIL.Image.Image image mode=L size=270x180>

# %%
cv2.imwrite("sunflower_grayscale_image.jpg",grayscale_image)
# Out:
# True
